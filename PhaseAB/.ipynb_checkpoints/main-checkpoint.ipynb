# %%
from src.phaseA import phaseA1, phaseA2, phaseA3
from src.phaseB import phaseB
from src.generators.image_generation.RuleBasedGenerator import RuleBasedGenerator
# Out:
# mongodb+srv://matheusberbet001:12345@amplicluster.0k26okc.mongodb.net/?retryWrites=true&w=majority&appName=AmpliCluster
# Pinged your deployment. You successfully connected to MongoDB!

# %%
path_to_imgs = "data/scanned_1/*" #DENV_imgs/*"
scanned_path = "data/scanned/"
display= False

# %%
# --- Phase A --- #
# Phase A.1 - Scanning images
Images = phaseA1(
    path_to_imgs, scanned_path,
    display=display, 
    do_white_balance=True,
    is_pre_scanned=True
)
# Out:
# # of Images to be analyzed: 76

# %%
# break images into batches
from math import ceil
from itertools import islice

def batch_dict(data_dict, batch_size):
    it = iter(data_dict.items())
    for i in range(0, len(data_dict), batch_size):
        yield {k: v for k, v in islice(it, batch_size)}

batch_size = 5
batches = list(batch_dict(Images, batch_size))

# %%
# Phase A.2 - Grids
print(" --- Grids --- ")
Grids = {}
for batch in batches:
    Grids.update(phaseA2(Images, display=True))
# Out:
#  --- Grids ---
# Building 'ovarian_img9_JPEG_scaned_jpg''s virtual grid...

# %%
# save test results
print(" --- Results --- ")
results = phaseB(Grids, display=display)

# %%
# Phase A.3 - Position Graph
print(" --- Graph --- ")
graphs = phaseA3(Grids, display=display)

# %%
# --- Image Generation --- #
print(" --- Image Generation --- ")
RBG = RuleBasedGenerator(graphs, results)
RBG.generate()
